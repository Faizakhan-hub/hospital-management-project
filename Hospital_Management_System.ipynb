# %%
class Hospital:
    l1=[]
    l2=[]
    l3=[]
    l4=[]
    l5=[]
    l6=[]
    l7=[]
    l8=[]
    l9=[]
    l10=[]
    l11=[]
    l12=[]
    l13=[]
    l14=[]
    l15=[]
    l16=[]
    l17=[]
    l18=[]
    l19=[]
    l20=[]
    l21=[]
    l22=[]
    l23=[]
    l24=[]
    l25=[]
    l26=[]
    l27=[]
    l28=[]
    l29=[]
    l30=[]
    l31=[]
    l32=[]
    l33=[]
    l34=[]
    l35=[]
    l36=[]
    l37=[]
    l38=[]
    l39=[]
    l40=[]
    l41=[]
    l42=[]
    l43=[]
    l44=[]
    l45=[]
    l46=[]
    l47=[]
    l48=[]
    l49=[]
    l50=[]
    l51=[]
    l52=[]
    l53=[]
    l54=[]
    l55=[]
    l56=[]
    l57=[]
    l58=[]
    l59=[]
    l60=[]
    def __init__(self):
        self.n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
        if (self.n==1):
            self.add_patient()
        elif (self.n==2):
            self.show_patient()
        elif (self.n==3):
            self.get_new_patient()
        elif (self.n==4):
            self.remove_patient()
        elif (self.n==5):
            print('''End of Program 
            THANK YOU!''')
        else:
            print("Enter a valid input")
            self.__init__()
    def add_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter in which Specialization you want to add the patient :
                '''))
        if m==1:
            if (len(self.l1)+len(self.l2)+len(self.l3))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
    
            else:
                name=input("Enter patient name in Allergy and Immunology department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l1.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l2.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l3.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==2:
            if (len(self.l4)+len(self.l5)+len(self.l6))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Anesthesiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l4.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l5.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l6.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==3:
            if (len(self.l7)+len(self.l8)+len(self.l9))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Dermatology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==4:
            if (len(self.l10)+len(self.l11)+len(self.l12))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            
            else:
                name=input("Enter patient name in Diagnostic radiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l10.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l11.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l12.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==5:
            if (len(self.l13)+len(self.l14)+len(self.l15))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Emergency medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l13.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l14.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l15.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()

        elif m==6:
            if (len(self.l16)+len(self.l17)+len(self.l18))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Family medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l16.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l17.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l18.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==7:
            if (len(self.l19)+len(self.l20)+len(self.l21))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Internal Medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l19.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l20.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l21.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==8:
            if (len(self.l22)+len(self.l23)+len(self.l24))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Medical genetics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l22.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l23.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l24.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==9:
            if (len(self.l25)+len(self.l26)+len(self.l27))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Neurology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l25.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l26.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l27.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==10:
            if (len(self.l28)+len(self.l29)+len(self.l30))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Nuclear medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l28.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l29.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l30.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==11:
            if (len(self.l31)+len(self.l32)+len(self.l33))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Obstetrics and gynecology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l31.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l32.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l33.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==12:
            if (len(self.l34)+len(self.l35)+len(self.l36))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Ophthalmology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l34.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l35.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l36.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==13:
            if (len(self.l37)+len(self.l38)+len(self.l39))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Pathology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l37.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l38.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l39.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==14:
            if (len(self.l40)+len(self.l41)+len(self.l42))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
                n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
            else:
                name=input("Enter patient name in Pediatrics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==15:
            if (len(self.l43)+len(self.l44)+len(self.l45))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Physical medicine and rehabilitation Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l43.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l44.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l45.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==16:
            if (len(self.l46)+len(self.l47)+len(self.l48))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Preventive medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l46.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l47.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l48.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==17:
            if (len(self.l49)+len(self.l50)+len(self.l51))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Psychiatry Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l49.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l50.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l51.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==18:
            if (len(self.l52)+len(self.l53)+len(self.l54))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Radiation oncology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l52.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l53.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l54.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==19:
            if (len(self.l55)+len(self.l56)+len(self.l57))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Surgery Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l55.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l56.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l57.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==20:
            if (len(self.l58)+len(self.l59)+len(self.l60))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")

            else:
                name=input("Enter patient name in Urology  Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l58.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l59.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l60.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        self.__init__()
    def show_patient(self):
        print()
        print("NUMBER OF PATIENTS IN DIFFERENT SPEACIALIZATIONS ARE :")
        if(len(self.l1)+len(self.l2)+len(self.l3))>0:
            print()
            print("Specialization 1 (Allergy and Immunology Department) : Total number of Patient is ",(len(self.l1)+len(self.l2)+len(self.l3)))
            for i in self.l1:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l2:
                print("Patient : ",i,"is Urgent")
            for i in self.l3:
                print("Patient : ",i,"is Normal")
    
        if (len(self.l4)+len(self.l5)+len(self.l6))>0:
            print()
            print("Specialization 2 (Anesthesiology Department) : Total number of Patient is ",(len(self.l4)+len(self.l5)+len(self.l6)))
            for i in self.l4:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l5:
                print("Patient : ",i,"is Urgent")
            for i in self.l6:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l7)+len(self.l8)+len(self.l9))>0:
            print()
            print("Specialization 3 (Dermatology Department) : Total number of Patient is ",(len(self.l7)+len(self.l8)+len(self.l9)))
            for i in self.l7:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l8:
                print("Patient : ",i,"is urgent")
            for i in self.l9:
                print("Patient : ",i,"is normal")
        
        if (len(self.l10)+len(self.l11)+len(self.l12))>0:
            print()
            print("Specialization 4 (Diagnostic Radiology Department) : Total number of Patient is ",(len(self.l10)+len(self.l11)+len(self.l12)))
            for i in self.l10:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l11:
                print("Patient : ",i,"is Urgent")
            for i in self.l12:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l13)+len(self.l14)+len(self.l15))>0:
            print()
            print("Specialization 5 (Emergency Medicine Department): Total number of Patient is ",(len(self.l13)+len(self.l14)+len(self.l15)))
            for i in self.l13:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l14:
                print("Patient : ",i,"is urgent")
            for i in self.l15:
                print("Patient : ",i,"is normal")
        
        if (len(self.l16)+len(self.l17)+len(self.l18))>0:
            print()
            print("Specialization 6 ( Family Medicine Department ) : Total number of Patient is ",(len(self.l16)+len(self.l17)+len(self.l18)))
            for i in self.l16:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l17:
                print("Patient : ",i,"is Urgent")
            for i in self.l18:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l19)+len(self.l20)+len(self.l21))>0:
            print()
            print("Specialization 7 (Internal Medicine Department ): Total number of Patient is ",(len(self.l19)+len(self.l20)+len(self.l21)))
            for i in self.l19:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l20:
                print("Patient : ",i,"is urgent")
            for i in self.l21:
                print("Patient : ",i,"is normal")
                
        if (len(self.l22)+len(self.l23)+len(self.l24))>0:
            print()
            print("Specialization 8 (Medical Genetics Department) : Total number of Patient is ",(len(self.l22)+len(self.l23)+len(self.l24)))
            for i in self.l22:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l23:
                print("Patient : ",i,"is Urgent")
            for i in self.l24:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l25)+len(self.l26)+len(self.l27))>0:
            print()
            print("Specialization 9 ( Neurology Department) : Total number of Patient is ",(len(self.l25)+len(self.l26)+len(self.l27)))
            for i in self.l25:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l26:
                print("Patient : ",i,"is urgent")
            for i in self.l27:
                print("Patient : ",i,"is normal")
                
        if (len(self.l28)+len(self.l29)+len(self.l30))>0:
            print()
            print("Specialization 10 (Nuclear Medicine Department) : Total number of Patient is ",(len(self.l28)+len(self.l29)+len(self.l30)))
            for i in self.l28:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l29:
                print("Patient : ",i,"is Urgent")
            for i in self.l30:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l31)+len(self.l32)+len(self.l33))>0:
            print()
            print("Specialization 11 (Obstetrics and Gynecology Department) : Total number of Patient is ",(len(self.l31)+len(self.l32)+len(self.l33)))
            for i in self.l31:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l32:
                print("Patient : ",i,"is urgent")
            for i in self.l33:
                print("Patient : ",i,"is normal")
                
        if (len(self.l34)+len(self.l35)+len(self.l36))>0:
            print()
            print("Specialization 12 (Ophthalmology Department) : Total number of Patient is ",(len(self.l34)+len(self.l35)+len(self.l36)))
            for i in self.l34:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l35:
                print("Patient : ",i,"is Urgent")
            for i in self.l36:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l37)+len(self.l38)+len(self.l39))>0:
            print()
            print("Specialization 13 (Pathology Department) : Total number of Patient is ",(len(self.l37)+len(self.l38)+len(self.l39)))
            for i in self.l37:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l38:
                print("Patient : ",i,"is urgent")
            for i in self.l39:
                print("Patient : ",i,"is normal")
                
        if (len(self.l40)+len(self.l41)+len(self.l42))>0:
            print()
            print("Specialization 14 (Pediatrics Department) : Total number of Patient is ",(len(self.l40)+len(self.l41)+len(self.l42)))
            for i in self.l40:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l41:
                print("Patient : ",i,"is Urgent")
            for i in self.l42:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l43)+len(self.l44)+len(self.l45))>0:
            print()
            print("Specialization 15 (Physical medicine and rehabilitation Department) : Total number of Patient is ",(len(self.l43)+len(self.l44)+len(self.l45)))
            for i in self.l43:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l44:
                print("Patient : ",i,"is urgent")
            for i in self.l45:
                print("Patient : ",i,"is normal")
        
        if (len(self.l46)+len(self.l47)+len(self.l48))>0:
            print()
            print("Specialization 16 (Preventive medicine Department) : Total number of Patient is ",(len(self.l46)+len(self.l47)+len(self.l48)))
            for i in self.l46:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l47:
                print("Patient : ",i,"is Urgent")
            for i in self.l48:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l49)+len(self.l50)+len(self.l51))>0:
            print()
            print("Specialization 17 (Psychiatry Department ) : Total number of Patient is ",(len(self.l49)+len(self.l50)+len(self.l51)))
            for i in self.l49:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l50:
                print("Patient : ",i,"is urgent")
            for i in self.l51:
                print("Patient : ",i,"is normal")
        
        if (len(self.l52)+len(self.l53)+len(self.l54))>0:
            print()
            print("Specialization 18 ( Radiation oncology Department) : Total number of Patient is ",(len(self.l52)+len(self.l53)+len(self.l54)))
            for i in self.l52:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l53:
                print("Patient : ",i,"is Urgent")
            for i in self.l54:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l55)+len(self.l56)+len(self.l57))>0:
            print()
            print("Specialization 19 (Surgery Department) : Total number of Patient is ",(len(self.l55)+len(self.l56)+len(self.l57)))
            for i in self.l55:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l56:
                print("Patient : ",i,"is urgent")
            for i in self.l57:
                print("Patient : ",i,"is normal")
                
        if (len(self.l58)+len(self.l59)+len(self.l60))>0:
            print()
            print("Specialization 20 (Urology Department) : Total number of Patient is ",(len(self.l58)+len(self.l59)+len(self.l60)))
            for i in self.l58:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l59:
                print("Patient : ",i,"is Urgent")
            for i in self.l60:
                print("Patient : ",i,"is Normal")
        self.__init__()
    def get_new_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter from which Specialization you want to get the patient :
                '''))
        if m==1:
            if len(self.l1)>0:
                print(self.l1[0],"Please go with the doctor!")
            elif len(self.l2)>0:
                print(self.l2[0],"Please go with the doctor!")
            elif len(self.l3)>0:
                print(self.l3[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==2:
            if len(self.l4)>0:
                print(self.l4[0],"Please go with the doctor!")
            elif len(self.l5)>0:
                print(self.l5[0],"Please go with the doctor!")
            elif len(self.l6)>0:
                print(self.l6[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==3:
            if len(self.l7)>0:
                print(self.l7[0],"Please go with the doctor!")
            elif len(self.l8)>0:
                print(self.l8[0],"Please go with the doctor!")
            elif len(self.l9)>0:
                print(self.l9[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==4:
            if len(self.l10)>0:
                print(self.l10[0],"Please go with the doctor!")
            elif len(self.l11)>0:
                print(self.l11[0],"Please go with the doctor!")
            elif len(self.l12)>0:
                print(self.l12[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==5:
            if len(self.l13)>0:
                print(self.l13[0],"Please go with the doctor!")
            elif len(self.l14)>0:
                print(self.l14[0],"Please go with the doctor!")
            elif len(self.l15)>0:
                print(self.l15[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==6:
            if len(self.l16)>0:
                print(self.l16[0],"Please go with the doctor!")
            elif len(self.l17)>0:
                print(self.l17[0],"Please go with the doctor!")
            elif len(self.l18)>0:
                print(self.l18[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==7:
            if len(self.l19)>0:
                print(self.l19[0],"Please go with the doctor!")
            elif len(self.l20)>0:
                print(self.l20[0],"Please go with the doctor!")
            elif len(self.l21)>0:
                print(self.l21[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==8:
            if len(self.l22)>0:
                print(self.l22[0],"Please go with the doctor!")
            elif len(self.l23)>0:
                print(self.l23[0],"Please go with the doctor!")
            elif len(self.l24)>0:
                print(self.l24[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==9:
            if len(self.l25)>0:
                print(self.l25[0],"Please go with the doctor!")
            elif len(self.l26)>0:
                print(self.l26[0],"Please go with the doctor!")
            elif len(self.l27)>0:
                print(self.l27[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==10:
            if len(self.l28)>0:
                print(self.l28[0],"Please go with the doctor!")
            elif len(self.l29)>0:
                print(self.l29[0],"Please go with the doctor!")
            elif len(self.l30)>0:
                print(self.l30[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        if m==11:
            if len(self.l31)>0:
                print(self.l31[0],"Please go with the doctor!")
            elif len(self.l32)>0:
                print(self.l32[0],"Please go with the doctor!")
            elif len(self.l33)>0:
                print(self.l33[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==12:
            if len(self.l34)>0:
                print(self.l34[0],"Please go with the doctor!")
            elif len(self.l35)>0:
                print(self.l35[0],"Please go with the doctor!")
            elif len(self.l36)>0:
                print(self.l36[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==13:
            if len(self.l37)>0:
                print(self.l37[0],"Please go with the doctor!")
            elif len(self.l38)>0:
                print(self.l38[0],"Please go with the doctor!")
            elif len(self.l39)>0:
                print(self.l39[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==14:
            if len(self.l40)>0:
                print(self.l40[0],"Please go with the doctor!")
            elif len(self.l41)>0:
                print(self.l41[0],"Please go with the doctor!")
            elif len(self.l42)>0:
                print(self.l42[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==15:
            if len(self.l43)>0:
                print(self.l43[0],"Please go with the doctor!")
            elif len(self.l44)>0:
                print(self.l44[0],"Please go with the doctor!")
            elif len(self.l45)>0:
                print(self.l45[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==16:
            if len(self.l46)>0:
                print(self.l46[0],"Please go with the doctor!")
            elif len(self.l47)>0:
                print(self.l47[0],"Please go with the doctor!")
            elif len(self.l48)>0:
                print(self.l48[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==17:
            if len(self.l49)>0:
                print(self.l49[0],"Please go with the doctor!")
            elif len(self.l50)>0:
                print(self.l50[0],"Please go with the doctor!")
            elif len(self.l51)>0:
                print(self.l51[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==18:
            if len(self.l52)>0:
                print(self.l52[0],"Please go with the doctor!")
            elif len(self.l53)>0:
                print(self.l53[0],"Please go with the doctor!")
            elif len(self.l54)>0:
                print(self.l54[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==19:
            if len(self.l55)>0:
                print(self.l55[0],"Please go with the doctor!")
            elif len(self.l56)>0:
                print(self.l56[0],"Please go with the doctor!")
            elif len(self.l57)>0:
                print(self.l57[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==20:
            if len(self.l58)>0:
                print(self.l58[0],"Please go with the doctor!")
            elif len(self.l59)>0:
                print(self.l59[0],"Please go with the doctor!")
            elif len(self.l60)>0:
                print(self.l60[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        self.__init__() 
    def remove_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter Specialization (1-20) from which you want to remove the patient :
                '''))
        if m==1:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l1:
                self.l1.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l2:
                self.l2.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l3:
                self.l3.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            else:
                print("No such patient in Specialization 1")   
        if m==2:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l4:
                self.l4.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l5:
                self.l5.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l6:
                self.l6.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            else:
                print("No such patient in Specialization 2")
        if m==3:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l7:
                self.l7.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l8:
                self.l8.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l9:
                self.l9.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            else:
                print("No such patient in Specialization 3")   
        if m==4:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l10:
                self.l10.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l11:
                self.l11.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l12:
                self.l12.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            else:
                print("No such patient in Specialization 4")
        if m==5:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l13:
                self.l13.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l14:
                self.l14.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l15:
                self.l15.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            else:
                print("No such patient in Specialization 5")   
        if m==6:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l16:
                self.l16.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l17:
                self.l17.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l18:
                self.l18.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            else:
                print("No such patient in Specialization 6")
        if m==7:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l19:
                self.l19.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l20:
                self.l20.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l21:
                self.l21.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            else:
                print("No such patient in Specialization 7")   
        if m==8:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l22:
                self.l22.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l23:
                self.l23.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l24:
                self.l24.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            else:
                print("No such patient in Specialization 8")
        if m==9:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l25:
                self.l25.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l26:
                self.l26.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l27:
                self.l27.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            else:
                print("No such patient in Specialization 9")   
        if m==10:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l28:
                self.l28.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l29:
                self.l29.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l30:
                self.l30.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            else:
                print("No such patient in Specialization 10")
        if m==11:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l31:
                self.l31.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l32:
                self.l32.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l33:
                self.l33.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            else:
                print("No such patient in Specialization 11")   
        if m==12:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l34:
                self.l34.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l35:
                self.l35.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l36:
                self.l36.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            else:
                print("No such patient in Specialization 12")
        if m==13:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l37:
                self.l37.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l38:
                self.l38.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l39:
                self.l39.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            else:
                print("No such patient in Specialization 13")   
        if m==14:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l40:
                self.l40.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            elif name in self.l41:
                self.l41.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42)) 
            elif name in self.l42:
                self.l42.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            else:
                print("No such patient in Specialization 14")
        if m==15:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l43:
                self.l43.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l44:
                self.l44.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l45:
                self.l45.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            else:
                print("No such patient in Specialization 15")   
        if m==16:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l46:
                self.l46.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l47:
                self.l47.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l48:
                self.l48.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            else:
                print("No such patient in Specialization 16")
        if m==17:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l49:
                self.l49.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l50:
                self.l50.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l51:
                self.l51.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            else:
                print("No such patient in Specialization 17")   
        if m==18:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l52:
                self.l52.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l53:
                self.l53.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l54:
                self.l54.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            else:
                print("No such patient in Specialization 18")
        if m==19:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l55:
                self.l55.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l56:
                self.l56.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l57:
                self.l57.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            else:
                print("No such patient in Specialization 19")   
        if m==20:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l58:
                self.l58.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l59:
                self.l59.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l60:
                self.l60.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            else:
                print("No such patient in Specialization 20")
        self.__init__()                
Hospital()


# In[ ]:




#!/usr/bin/env python
# coding: utf-8

# In[1]:


class Hospital:
    l1=[]
    l2=[]
    l3=[]
    l4=[]
    l5=[]
    l6=[]
    l7=[]
    l8=[]
    l9=[]
    l10=[]
    l11=[]
    l12=[]
    l13=[]
    l14=[]
    l15=[]
    l16=[]
    l17=[]
    l18=[]
    l19=[]
    l20=[]
    l21=[]
    l22=[]
    l23=[]
    l24=[]
    l25=[]
    l26=[]
    l27=[]
    l28=[]
    l29=[]
    l30=[]
    l31=[]
    l32=[]
    l33=[]
    l34=[]
    l35=[]
    l36=[]
    l37=[]
    l38=[]
    l39=[]
    l40=[]
    l41=[]
    l42=[]
    l43=[]
    l44=[]
    l45=[]
    l46=[]
    l47=[]
    l48=[]
    l49=[]
    l50=[]
    l51=[]
    l52=[]
    l53=[]
    l54=[]
    l55=[]
    l56=[]
    l57=[]
    l58=[]
    l59=[]
    l60=[]
    def __init__(self):
        self.n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
        if (self.n==1):
            self.add_patient()
        elif (self.n==2):
            self.show_patient()
        elif (self.n==3):
            self.get_new_patient()
        elif (self.n==4):
            self.remove_patient()
        elif (self.n==5):
            print('''End of Program 
            THANK YOU!''')
        else:
            print("Enter a valid input")
            self.__init__()
    def add_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter in which Specialization you want to add the patient :
                '''))
        if m==1:
            if (len(self.l1)+len(self.l2)+len(self.l3))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
    
            else:
                name=input("Enter patient name in Allergy and Immunology department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l1.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l2.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l3.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==2:
            if (len(self.l4)+len(self.l5)+len(self.l6))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Anesthesiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l4.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l5.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l6.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==3:
            if (len(self.l7)+len(self.l8)+len(self.l9))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Dermatology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==4:
            if (len(self.l10)+len(self.l11)+len(self.l12))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            
            else:
                name=input("Enter patient name in Diagnostic radiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l10.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l11.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l12.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==5:
            if (len(self.l13)+len(self.l14)+len(self.l15))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Emergency medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l13.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l14.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l15.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()

        elif m==6:
            if (len(self.l16)+len(self.l17)+len(self.l18))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Family medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l16.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l17.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l18.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==7:
            if (len(self.l19)+len(self.l20)+len(self.l21))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Internal Medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l19.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l20.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l21.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==8:
            if (len(self.l22)+len(self.l23)+len(self.l24))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Medical genetics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l22.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l23.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l24.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==9:
            if (len(self.l25)+len(self.l26)+len(self.l27))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Neurology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l25.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l26.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l27.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==10:
            if (len(self.l28)+len(self.l29)+len(self.l30))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Nuclear medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l28.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l29.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l30.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==11:
            if (len(self.l31)+len(self.l32)+len(self.l33))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Obstetrics and gynecology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l31.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l32.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l33.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==12:
            if (len(self.l34)+len(self.l35)+len(self.l36))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Ophthalmology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l34.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l35.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l36.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==13:
            if (len(self.l37)+len(self.l38)+len(self.l39))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Pathology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l37.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l38.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l39.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==14:
            if (len(self.l40)+len(self.l41)+len(self.l42))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
                n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
            else:
                name=input("Enter patient name in Pediatrics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==15:
            if (len(self.l43)+len(self.l44)+len(self.l45))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Physical medicine and rehabilitation Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l43.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l44.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l45.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==16:
            if (len(self.l46)+len(self.l47)+len(self.l48))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Preventive medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l46.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l47.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l48.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==17:
            if (len(self.l49)+len(self.l50)+len(self.l51))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Psychiatry Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l49.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l50.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l51.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==18:
            if (len(self.l52)+len(self.l53)+len(self.l54))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Radiation oncology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l52.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l53.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l54.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==19:
            if (len(self.l55)+len(self.l56)+len(self.l57))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Surgery Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l55.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l56.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l57.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==20:
            if (len(self.l58)+len(self.l59)+len(self.l60))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")

            else:
                name=input("Enter patient name in Urology  Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l58.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l59.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l60.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        self.__init__()
    def show_patient(self):
        print()
        print("NUMBER OF PATIENTS IN DIFFERENT SPEACIALIZATIONS ARE :")
        if(len(self.l1)+len(self.l2)+len(self.l3))>0:
            print()
            print("Specialization 1 (Allergy and Immunology Department) : Total number of Patient is ",(len(self.l1)+len(self.l2)+len(self.l3)))
            for i in self.l1:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l2:
                print("Patient : ",i,"is Urgent")
            for i in self.l3:
                print("Patient : ",i,"is Normal")
    
        if (len(self.l4)+len(self.l5)+len(self.l6))>0:
            print()
            print("Specialization 2 (Anesthesiology Department) : Total number of Patient is ",(len(self.l4)+len(self.l5)+len(self.l6)))
            for i in self.l4:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l5:
                print("Patient : ",i,"is Urgent")
            for i in self.l6:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l7)+len(self.l8)+len(self.l9))>0:
            print()
            print("Specialization 3 (Dermatology Department) : Total number of Patient is ",(len(self.l7)+len(self.l8)+len(self.l9)))
            for i in self.l7:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l8:
                print("Patient : ",i,"is urgent")
            for i in self.l9:
                print("Patient : ",i,"is normal")
        
        if (len(self.l10)+len(self.l11)+len(self.l12))>0:
            print()
            print("Specialization 4 (Diagnostic Radiology Department) : Total number of Patient is ",(len(self.l10)+len(self.l11)+len(self.l12)))
            for i in self.l10:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l11:
                print("Patient : ",i,"is Urgent")
            for i in self.l12:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l13)+len(self.l14)+len(self.l15))>0:
            print()
            print("Specialization 5 (Emergency Medicine Department): Total number of Patient is ",(len(self.l13)+len(self.l14)+len(self.l15)))
            for i in self.l13:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l14:
                print("Patient : ",i,"is urgent")
            for i in self.l15:
                print("Patient : ",i,"is normal")
        
        if (len(self.l16)+len(self.l17)+len(self.l18))>0:
            print()
            print("Specialization 6 ( Family Medicine Department ) : Total number of Patient is ",(len(self.l16)+len(self.l17)+len(self.l18)))
            for i in self.l16:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l17:
                print("Patient : ",i,"is Urgent")
            for i in self.l18:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l19)+len(self.l20)+len(self.l21))>0:
            print()
            print("Specialization 7 (Internal Medicine Department ): Total number of Patient is ",(len(self.l19)+len(self.l20)+len(self.l21)))
            for i in self.l19:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l20:
                print("Patient : ",i,"is urgent")
            for i in self.l21:
                print("Patient : ",i,"is normal")
                
        if (len(self.l22)+len(self.l23)+len(self.l24))>0:
            print()
            print("Specialization 8 (Medical Genetics Department) : Total number of Patient is ",(len(self.l22)+len(self.l23)+len(self.l24)))
            for i in self.l22:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l23:
                print("Patient : ",i,"is Urgent")
            for i in self.l24:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l25)+len(self.l26)+len(self.l27))>0:
            print()
            print("Specialization 9 ( Neurology Department) : Total number of Patient is ",(len(self.l25)+len(self.l26)+len(self.l27)))
            for i in self.l25:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l26:
                print("Patient : ",i,"is urgent")
            for i in self.l27:
                print("Patient : ",i,"is normal")
                
        if (len(self.l28)+len(self.l29)+len(self.l30))>0:
            print()
            print("Specialization 10 (Nuclear Medicine Department) : Total number of Patient is ",(len(self.l28)+len(self.l29)+len(self.l30)))
            for i in self.l28:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l29:
                print("Patient : ",i,"is Urgent")
            for i in self.l30:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l31)+len(self.l32)+len(self.l33))>0:
            print()
            print("Specialization 11 (Obstetrics and Gynecology Department) : Total number of Patient is ",(len(self.l31)+len(self.l32)+len(self.l33)))
            for i in self.l31:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l32:
                print("Patient : ",i,"is urgent")
            for i in self.l33:
                print("Patient : ",i,"is normal")
                
        if (len(self.l34)+len(self.l35)+len(self.l36))>0:
            print()
            print("Specialization 12 (Ophthalmology Department) : Total number of Patient is ",(len(self.l34)+len(self.l35)+len(self.l36)))
            for i in self.l34:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l35:
                print("Patient : ",i,"is Urgent")
            for i in self.l36:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l37)+len(self.l38)+len(self.l39))>0:
            print()
            print("Specialization 13 (Pathology Department) : Total number of Patient is ",(len(self.l37)+len(self.l38)+len(self.l39)))
            for i in self.l37:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l38:
                print("Patient : ",i,"is urgent")
            for i in self.l39:
                print("Patient : ",i,"is normal")
                
        if (len(self.l40)+len(self.l41)+len(self.l42))>0:
            print()
            print("Specialization 14 (Pediatrics Department) : Total number of Patient is ",(len(self.l40)+len(self.l41)+len(self.l42)))
            for i in self.l40:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l41:
                print("Patient : ",i,"is Urgent")
            for i in self.l42:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l43)+len(self.l44)+len(self.l45))>0:
            print()
            print("Specialization 15 (Physical medicine and rehabilitation Department) : Total number of Patient is ",(len(self.l43)+len(self.l44)+len(self.l45)))
            for i in self.l43:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l44:
                print("Patient : ",i,"is urgent")
            for i in self.l45:
                print("Patient : ",i,"is normal")
        
        if (len(self.l46)+len(self.l47)+len(self.l48))>0:
            print()
            print("Specialization 16 (Preventive medicine Department) : Total number of Patient is ",(len(self.l46)+len(self.l47)+len(self.l48)))
            for i in self.l46:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l47:
                print("Patient : ",i,"is Urgent")
            for i in self.l48:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l49)+len(self.l50)+len(self.l51))>0:
            print()
            print("Specialization 17 (Psychiatry Department ) : Total number of Patient is ",(len(self.l49)+len(self.l50)+len(self.l51)))
            for i in self.l49:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l50:
                print("Patient : ",i,"is urgent")
            for i in self.l51:
                print("Patient : ",i,"is normal")
        
        if (len(self.l52)+len(self.l53)+len(self.l54))>0:
            print()
            print("Specialization 18 ( Radiation oncology Department) : Total number of Patient is ",(len(self.l52)+len(self.l53)+len(self.l54)))
            for i in self.l52:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l53:
                print("Patient : ",i,"is Urgent")
            for i in self.l54:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l55)+len(self.l56)+len(self.l57))>0:
            print()
            print("Specialization 19 (Surgery Department) : Total number of Patient is ",(len(self.l55)+len(self.l56)+len(self.l57)))
            for i in self.l55:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l56:
                print("Patient : ",i,"is urgent")
            for i in self.l57:
                print("Patient : ",i,"is normal")
                
        if (len(self.l58)+len(self.l59)+len(self.l60))>0:
            print()
            print("Specialization 20 (Urology Department) : Total number of Patient is ",(len(self.l58)+len(self.l59)+len(self.l60)))
            for i in self.l58:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l59:
                print("Patient : ",i,"is Urgent")
            for i in self.l60:
                print("Patient : ",i,"is Normal")
        self.__init__()
    def get_new_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter from which Specialization you want to get the patient :
                '''))
        if m==1:
            if len(self.l1)>0:
                print(self.l1[0],"Please go with the doctor!")
            elif len(self.l2)>0:
                print(self.l2[0],"Please go with the doctor!")
            elif len(self.l3)>0:
                print(self.l3[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==2:
            if len(self.l4)>0:
                print(self.l4[0],"Please go with the doctor!")
            elif len(self.l5)>0:
                print(self.l5[0],"Please go with the doctor!")
            elif len(self.l6)>0:
                print(self.l6[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==3:
            if len(self.l7)>0:
                print(self.l7[0],"Please go with the doctor!")
            elif len(self.l8)>0:
                print(self.l8[0],"Please go with the doctor!")
            elif len(self.l9)>0:
                print(self.l9[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==4:
            if len(self.l10)>0:
                print(self.l10[0],"Please go with the doctor!")
            elif len(self.l11)>0:
                print(self.l11[0],"Please go with the doctor!")
            elif len(self.l12)>0:
                print(self.l12[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==5:
            if len(self.l13)>0:
                print(self.l13[0],"Please go with the doctor!")
            elif len(self.l14)>0:
                print(self.l14[0],"Please go with the doctor!")
            elif len(self.l15)>0:
                print(self.l15[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==6:
            if len(self.l16)>0:
                print(self.l16[0],"Please go with the doctor!")
            elif len(self.l17)>0:
                print(self.l17[0],"Please go with the doctor!")
            elif len(self.l18)>0:
                print(self.l18[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==7:
            if len(self.l19)>0:
                print(self.l19[0],"Please go with the doctor!")
            elif len(self.l20)>0:
                print(self.l20[0],"Please go with the doctor!")
            elif len(self.l21)>0:
                print(self.l21[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==8:
            if len(self.l22)>0:
                print(self.l22[0],"Please go with the doctor!")
            elif len(self.l23)>0:
                print(self.l23[0],"Please go with the doctor!")
            elif len(self.l24)>0:
                print(self.l24[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==9:
            if len(self.l25)>0:
                print(self.l25[0],"Please go with the doctor!")
            elif len(self.l26)>0:
                print(self.l26[0],"Please go with the doctor!")
            elif len(self.l27)>0:
                print(self.l27[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==10:
            if len(self.l28)>0:
                print(self.l28[0],"Please go with the doctor!")
            elif len(self.l29)>0:
                print(self.l29[0],"Please go with the doctor!")
            elif len(self.l30)>0:
                print(self.l30[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        if m==11:
            if len(self.l31)>0:
                print(self.l31[0],"Please go with the doctor!")
            elif len(self.l32)>0:
                print(self.l32[0],"Please go with the doctor!")
            elif len(self.l33)>0:
                print(self.l33[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==12:
            if len(self.l34)>0:
                print(self.l34[0],"Please go with the doctor!")
            elif len(self.l35)>0:
                print(self.l35[0],"Please go with the doctor!")
            elif len(self.l36)>0:
                print(self.l36[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==13:
            if len(self.l37)>0:
                print(self.l37[0],"Please go with the doctor!")
            elif len(self.l38)>0:
                print(self.l38[0],"Please go with the doctor!")
            elif len(self.l39)>0:
                print(self.l39[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==14:
            if len(self.l40)>0:
                print(self.l40[0],"Please go with the doctor!")
            elif len(self.l41)>0:
                print(self.l41[0],"Please go with the doctor!")
            elif len(self.l42)>0:
                print(self.l42[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==15:
            if len(self.l43)>0:
                print(self.l43[0],"Please go with the doctor!")
            elif len(self.l44)>0:
                print(self.l44[0],"Please go with the doctor!")
            elif len(self.l45)>0:
                print(self.l45[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==16:
            if len(self.l46)>0:
                print(self.l46[0],"Please go with the doctor!")
            elif len(self.l47)>0:
                print(self.l47[0],"Please go with the doctor!")
            elif len(self.l48)>0:
                print(self.l48[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==17:
            if len(self.l49)>0:
                print(self.l49[0],"Please go with the doctor!")
            elif len(self.l50)>0:
                print(self.l50[0],"Please go with the doctor!")
            elif len(self.l51)>0:
                print(self.l51[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==18:
            if len(self.l52)>0:
                print(self.l52[0],"Please go with the doctor!")
            elif len(self.l53)>0:
                print(self.l53[0],"Please go with the doctor!")
            elif len(self.l54)>0:
                print(self.l54[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==19:
            if len(self.l55)>0:
                print(self.l55[0],"Please go with the doctor!")
            elif len(self.l56)>0:
                print(self.l56[0],"Please go with the doctor!")
            elif len(self.l57)>0:
                print(self.l57[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==20:
            if len(self.l58)>0:
                print(self.l58[0],"Please go with the doctor!")
            elif len(self.l59)>0:
                print(self.l59[0],"Please go with the doctor!")
            elif len(self.l60)>0:
                print(self.l60[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        self.__init__() 
    def remove_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter Specialization (1-20) from which you want to remove the patient :
                '''))
        if m==1:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l1:
                self.l1.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l2:
                self.l2.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l3:
                self.l3.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            else:
                print("No such patient in Specialization 1")   
        if m==2:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l4:
                self.l4.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l5:
                self.l5.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l6:
                self.l6.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            else:
                print("No such patient in Specialization 2")
        if m==3:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l7:
                self.l7.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l8:
                self.l8.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l9:
                self.l9.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            else:
                print("No such patient in Specialization 3")   
        if m==4:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l10:
                self.l10.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l11:
                self.l11.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l12:
                self.l12.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            else:
                print("No such patient in Specialization 4")
        if m==5:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l13:
                self.l13.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l14:
                self.l14.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l15:
                self.l15.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            else:
                print("No such patient in Specialization 5")   
        if m==6:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l16:
                self.l16.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l17:
                self.l17.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l18:
                self.l18.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            else:
                print("No such patient in Specialization 6")
        if m==7:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l19:
                self.l19.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l20:
                self.l20.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l21:
                self.l21.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            else:
                print("No such patient in Specialization 7")   
        if m==8:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l22:
                self.l22.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l23:
                self.l23.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l24:
                self.l24.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            else:
                print("No such patient in Specialization 8")
        if m==9:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l25:
                self.l25.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l26:
                self.l26.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l27:
                self.l27.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            else:
                print("No such patient in Specialization 9")   
        if m==10:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l28:
                self.l28.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l29:
                self.l29.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l30:
                self.l30.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            else:
                print("No such patient in Specialization 10")
        if m==11:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l31:
                self.l31.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l32:
                self.l32.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l33:
                self.l33.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            else:
                print("No such patient in Specialization 11")   
        if m==12:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l34:
                self.l34.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l35:
                self.l35.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l36:
                self.l36.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            else:
                print("No such patient in Specialization 12")
        if m==13:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l37:
                self.l37.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l38:
                self.l38.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l39:
                self.l39.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            else:
                print("No such patient in Specialization 13")   
        if m==14:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l40:
                self.l40.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            elif name in self.l41:
                self.l41.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42)) 
            elif name in self.l42:
                self.l42.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            else:
                print("No such patient in Specialization 14")
        if m==15:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l43:
                self.l43.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l44:
                self.l44.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l45:
                self.l45.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            else:
                print("No such patient in Specialization 15")   
        if m==16:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l46:
                self.l46.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l47:
                self.l47.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l48:
                self.l48.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            else:
                print("No such patient in Specialization 16")
        if m==17:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l49:
                self.l49.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l50:
                self.l50.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l51:
                self.l51.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            else:
                print("No such patient in Specialization 17")   
        if m==18:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l52:
                self.l52.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l53:
                self.l53.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l54:
                self.l54.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            else:
                print("No such patient in Specialization 18")
        if m==19:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l55:
                self.l55.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l56:
                self.l56.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l57:
                self.l57.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            else:
                print("No such patient in Specialization 19")   
        if m==20:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l58:
                self.l58.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l59:
                self.l59.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l60:
                self.l60.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            else:
                print("No such patient in Specialization 20")
        self.__init__()                
Hospital()


# In[ ]:




#!/usr/bin/env python
# coding: utf-8

# In[1]:


class Hospital:
    l1=[]
    l2=[]
    l3=[]
    l4=[]
    l5=[]
    l6=[]
    l7=[]
    l8=[]
    l9=[]
    l10=[]
    l11=[]
    l12=[]
    l13=[]
    l14=[]
    l15=[]
    l16=[]
    l17=[]
    l18=[]
    l19=[]
    l20=[]
    l21=[]
    l22=[]
    l23=[]
    l24=[]
    l25=[]
    l26=[]
    l27=[]
    l28=[]
    l29=[]
    l30=[]
    l31=[]
    l32=[]
    l33=[]
    l34=[]
    l35=[]
    l36=[]
    l37=[]
    l38=[]
    l39=[]
    l40=[]
    l41=[]
    l42=[]
    l43=[]
    l44=[]
    l45=[]
    l46=[]
    l47=[]
    l48=[]
    l49=[]
    l50=[]
    l51=[]
    l52=[]
    l53=[]
    l54=[]
    l55=[]
    l56=[]
    l57=[]
    l58=[]
    l59=[]
    l60=[]
    def __init__(self):
        self.n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
        if (self.n==1):
            self.add_patient()
        elif (self.n==2):
            self.show_patient()
        elif (self.n==3):
            self.get_new_patient()
        elif (self.n==4):
            self.remove_patient()
        elif (self.n==5):
            print('''End of Program 
            THANK YOU!''')
        else:
            print("Enter a valid input")
            self.__init__()
    def add_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter in which Specialization you want to add the patient :
                '''))
        if m==1:
            if (len(self.l1)+len(self.l2)+len(self.l3))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
    
            else:
                name=input("Enter patient name in Allergy and Immunology department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l1.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l2.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l3.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==2:
            if (len(self.l4)+len(self.l5)+len(self.l6))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Anesthesiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l4.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l5.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l6.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==3:
            if (len(self.l7)+len(self.l8)+len(self.l9))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Dermatology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==4:
            if (len(self.l10)+len(self.l11)+len(self.l12))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            
            else:
                name=input("Enter patient name in Diagnostic radiology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l10.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l11.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l12.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==5:
            if (len(self.l13)+len(self.l14)+len(self.l15))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Emergency medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l13.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l14.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l15.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()

        elif m==6:
            if (len(self.l16)+len(self.l17)+len(self.l18))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Family medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l16.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l17.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l18.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==7:
            if (len(self.l19)+len(self.l20)+len(self.l21))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Internal Medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l19.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l20.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l21.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==8:
            if (len(self.l22)+len(self.l23)+len(self.l24))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Medical genetics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l22.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l23.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l24.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==9:
            if (len(self.l25)+len(self.l26)+len(self.l27))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Neurology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l25.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l26.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l27.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==10:
            if (len(self.l28)+len(self.l29)+len(self.l30))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Nuclear medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l28.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l29.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l30.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==11:
            if (len(self.l31)+len(self.l32)+len(self.l33))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Obstetrics and gynecology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l31.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l32.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l33.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==12:
            if (len(self.l34)+len(self.l35)+len(self.l36))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Ophthalmology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l34.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l35.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l36.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==13:
            if (len(self.l37)+len(self.l38)+len(self.l39))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Pathology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l37.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l38.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l39.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==14:
            if (len(self.l40)+len(self.l41)+len(self.l42))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
                n=int(input('''Program Options :\nEnter 1 to add a new patient \nEnter 2 to print all the patient \nEnter 3 to get next patient \nEnter 4 to remove a leaving patient \nEnter 5 to End the program \nEnter your choice :  '''))
            else:
                name=input("Enter patient name in Pediatrics Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l7.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l8.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l9.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==15:
            if (len(self.l43)+len(self.l44)+len(self.l45))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Physical medicine and rehabilitation Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l43.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l44.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l45.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==16:
            if (len(self.l46)+len(self.l47)+len(self.l48))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Preventive medicine Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l46.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l47.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l48.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==17:
            if (len(self.l49)+len(self.l50)+len(self.l51))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Psychiatry Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l49.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l50.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l51.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==18:
            if (len(self.l52)+len(self.l53)+len(self.l54))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Radiation oncology Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l52.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l53.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l54.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==19:
            if (len(self.l55)+len(self.l56)+len(self.l57))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")
            else:
                name=input("Enter patient name in Surgery Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l55.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l56.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l57.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        elif m==20:
            if (len(self.l58)+len(self.l59)+len(self.l60))>=10:
                print("Sorry we can not add more patients for this specialization at the moment ! ")

            else:
                name=input("Enter patient name in Urology  Department : ").upper()
                status=int(input("Enter the status \n 0 for Super Urgent \n 1 for urgent \n 2 for normal \n"))
                if status==0:
                    self.l58.append(name)
                    print("Patient Added Successfully !")
                elif status==1:
                    self.l59.append(name)
                    print("Patient Added Successfully !")
                elif status==2:
                    self.l60.append(name)
                    print("Patient Added Successfully !")
                else:
                    print("Invalid Input! Please add patient again.")
                    self.add_patient()
        self.__init__()
    def show_patient(self):
        print()
        print("NUMBER OF PATIENTS IN DIFFERENT SPEACIALIZATIONS ARE :")
        if(len(self.l1)+len(self.l2)+len(self.l3))>0:
            print()
            print("Specialization 1 (Allergy and Immunology Department) : Total number of Patient is ",(len(self.l1)+len(self.l2)+len(self.l3)))
            for i in self.l1:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l2:
                print("Patient : ",i,"is Urgent")
            for i in self.l3:
                print("Patient : ",i,"is Normal")
    
        if (len(self.l4)+len(self.l5)+len(self.l6))>0:
            print()
            print("Specialization 2 (Anesthesiology Department) : Total number of Patient is ",(len(self.l4)+len(self.l5)+len(self.l6)))
            for i in self.l4:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l5:
                print("Patient : ",i,"is Urgent")
            for i in self.l6:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l7)+len(self.l8)+len(self.l9))>0:
            print()
            print("Specialization 3 (Dermatology Department) : Total number of Patient is ",(len(self.l7)+len(self.l8)+len(self.l9)))
            for i in self.l7:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l8:
                print("Patient : ",i,"is urgent")
            for i in self.l9:
                print("Patient : ",i,"is normal")
        
        if (len(self.l10)+len(self.l11)+len(self.l12))>0:
            print()
            print("Specialization 4 (Diagnostic Radiology Department) : Total number of Patient is ",(len(self.l10)+len(self.l11)+len(self.l12)))
            for i in self.l10:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l11:
                print("Patient : ",i,"is Urgent")
            for i in self.l12:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l13)+len(self.l14)+len(self.l15))>0:
            print()
            print("Specialization 5 (Emergency Medicine Department): Total number of Patient is ",(len(self.l13)+len(self.l14)+len(self.l15)))
            for i in self.l13:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l14:
                print("Patient : ",i,"is urgent")
            for i in self.l15:
                print("Patient : ",i,"is normal")
        
        if (len(self.l16)+len(self.l17)+len(self.l18))>0:
            print()
            print("Specialization 6 ( Family Medicine Department ) : Total number of Patient is ",(len(self.l16)+len(self.l17)+len(self.l18)))
            for i in self.l16:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l17:
                print("Patient : ",i,"is Urgent")
            for i in self.l18:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l19)+len(self.l20)+len(self.l21))>0:
            print()
            print("Specialization 7 (Internal Medicine Department ): Total number of Patient is ",(len(self.l19)+len(self.l20)+len(self.l21)))
            for i in self.l19:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l20:
                print("Patient : ",i,"is urgent")
            for i in self.l21:
                print("Patient : ",i,"is normal")
                
        if (len(self.l22)+len(self.l23)+len(self.l24))>0:
            print()
            print("Specialization 8 (Medical Genetics Department) : Total number of Patient is ",(len(self.l22)+len(self.l23)+len(self.l24)))
            for i in self.l22:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l23:
                print("Patient : ",i,"is Urgent")
            for i in self.l24:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l25)+len(self.l26)+len(self.l27))>0:
            print()
            print("Specialization 9 ( Neurology Department) : Total number of Patient is ",(len(self.l25)+len(self.l26)+len(self.l27)))
            for i in self.l25:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l26:
                print("Patient : ",i,"is urgent")
            for i in self.l27:
                print("Patient : ",i,"is normal")
                
        if (len(self.l28)+len(self.l29)+len(self.l30))>0:
            print()
            print("Specialization 10 (Nuclear Medicine Department) : Total number of Patient is ",(len(self.l28)+len(self.l29)+len(self.l30)))
            for i in self.l28:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l29:
                print("Patient : ",i,"is Urgent")
            for i in self.l30:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l31)+len(self.l32)+len(self.l33))>0:
            print()
            print("Specialization 11 (Obstetrics and Gynecology Department) : Total number of Patient is ",(len(self.l31)+len(self.l32)+len(self.l33)))
            for i in self.l31:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l32:
                print("Patient : ",i,"is urgent")
            for i in self.l33:
                print("Patient : ",i,"is normal")
                
        if (len(self.l34)+len(self.l35)+len(self.l36))>0:
            print()
            print("Specialization 12 (Ophthalmology Department) : Total number of Patient is ",(len(self.l34)+len(self.l35)+len(self.l36)))
            for i in self.l34:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l35:
                print("Patient : ",i,"is Urgent")
            for i in self.l36:
                print("Patient : ",i,"is Normal")
                
        if (len(self.l37)+len(self.l38)+len(self.l39))>0:
            print()
            print("Specialization 13 (Pathology Department) : Total number of Patient is ",(len(self.l37)+len(self.l38)+len(self.l39)))
            for i in self.l37:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l38:
                print("Patient : ",i,"is urgent")
            for i in self.l39:
                print("Patient : ",i,"is normal")
                
        if (len(self.l40)+len(self.l41)+len(self.l42))>0:
            print()
            print("Specialization 14 (Pediatrics Department) : Total number of Patient is ",(len(self.l40)+len(self.l41)+len(self.l42)))
            for i in self.l40:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l41:
                print("Patient : ",i,"is Urgent")
            for i in self.l42:
                print("Patient : ",i,"is Normal")
            
        if (len(self.l43)+len(self.l44)+len(self.l45))>0:
            print()
            print("Specialization 15 (Physical medicine and rehabilitation Department) : Total number of Patient is ",(len(self.l43)+len(self.l44)+len(self.l45)))
            for i in self.l43:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l44:
                print("Patient : ",i,"is urgent")
            for i in self.l45:
                print("Patient : ",i,"is normal")
        
        if (len(self.l46)+len(self.l47)+len(self.l48))>0:
            print()
            print("Specialization 16 (Preventive medicine Department) : Total number of Patient is ",(len(self.l46)+len(self.l47)+len(self.l48)))
            for i in self.l46:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l47:
                print("Patient : ",i,"is Urgent")
            for i in self.l48:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l49)+len(self.l50)+len(self.l51))>0:
            print()
            print("Specialization 17 (Psychiatry Department ) : Total number of Patient is ",(len(self.l49)+len(self.l50)+len(self.l51)))
            for i in self.l49:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l50:
                print("Patient : ",i,"is urgent")
            for i in self.l51:
                print("Patient : ",i,"is normal")
        
        if (len(self.l52)+len(self.l53)+len(self.l54))>0:
            print()
            print("Specialization 18 ( Radiation oncology Department) : Total number of Patient is ",(len(self.l52)+len(self.l53)+len(self.l54)))
            for i in self.l52:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l53:
                print("Patient : ",i,"is Urgent")
            for i in self.l54:
                print("Patient : ",i,"is Normal")
        
        if (len(self.l55)+len(self.l56)+len(self.l57))>0:
            print()
            print("Specialization 19 (Surgery Department) : Total number of Patient is ",(len(self.l55)+len(self.l56)+len(self.l57)))
            for i in self.l55:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l56:
                print("Patient : ",i,"is urgent")
            for i in self.l57:
                print("Patient : ",i,"is normal")
                
        if (len(self.l58)+len(self.l59)+len(self.l60))>0:
            print()
            print("Specialization 20 (Urology Department) : Total number of Patient is ",(len(self.l58)+len(self.l59)+len(self.l60)))
            for i in self.l58:
                print("Patient : ",i,"is Super Urgent")
            for i in self.l59:
                print("Patient : ",i,"is Urgent")
            for i in self.l60:
                print("Patient : ",i,"is Normal")
        self.__init__()
    def get_new_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter from which Specialization you want to get the patient :
                '''))
        if m==1:
            if len(self.l1)>0:
                print(self.l1[0],"Please go with the doctor!")
            elif len(self.l2)>0:
                print(self.l2[0],"Please go with the doctor!")
            elif len(self.l3)>0:
                print(self.l3[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==2:
            if len(self.l4)>0:
                print(self.l4[0],"Please go with the doctor!")
            elif len(self.l5)>0:
                print(self.l5[0],"Please go with the doctor!")
            elif len(self.l6)>0:
                print(self.l6[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==3:
            if len(self.l7)>0:
                print(self.l7[0],"Please go with the doctor!")
            elif len(self.l8)>0:
                print(self.l8[0],"Please go with the doctor!")
            elif len(self.l9)>0:
                print(self.l9[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==4:
            if len(self.l10)>0:
                print(self.l10[0],"Please go with the doctor!")
            elif len(self.l11)>0:
                print(self.l11[0],"Please go with the doctor!")
            elif len(self.l12)>0:
                print(self.l12[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==5:
            if len(self.l13)>0:
                print(self.l13[0],"Please go with the doctor!")
            elif len(self.l14)>0:
                print(self.l14[0],"Please go with the doctor!")
            elif len(self.l15)>0:
                print(self.l15[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==6:
            if len(self.l16)>0:
                print(self.l16[0],"Please go with the doctor!")
            elif len(self.l17)>0:
                print(self.l17[0],"Please go with the doctor!")
            elif len(self.l18)>0:
                print(self.l18[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==7:
            if len(self.l19)>0:
                print(self.l19[0],"Please go with the doctor!")
            elif len(self.l20)>0:
                print(self.l20[0],"Please go with the doctor!")
            elif len(self.l21)>0:
                print(self.l21[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==8:
            if len(self.l22)>0:
                print(self.l22[0],"Please go with the doctor!")
            elif len(self.l23)>0:
                print(self.l23[0],"Please go with the doctor!")
            elif len(self.l24)>0:
                print(self.l24[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==9:
            if len(self.l25)>0:
                print(self.l25[0],"Please go with the doctor!")
            elif len(self.l26)>0:
                print(self.l26[0],"Please go with the doctor!")
            elif len(self.l27)>0:
                print(self.l27[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==10:
            if len(self.l28)>0:
                print(self.l28[0],"Please go with the doctor!")
            elif len(self.l29)>0:
                print(self.l29[0],"Please go with the doctor!")
            elif len(self.l30)>0:
                print(self.l30[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        if m==11:
            if len(self.l31)>0:
                print(self.l31[0],"Please go with the doctor!")
            elif len(self.l32)>0:
                print(self.l32[0],"Please go with the doctor!")
            elif len(self.l33)>0:
                print(self.l33[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==12:
            if len(self.l34)>0:
                print(self.l34[0],"Please go with the doctor!")
            elif len(self.l35)>0:
                print(self.l35[0],"Please go with the doctor!")
            elif len(self.l36)>0:
                print(self.l36[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==13:
            if len(self.l37)>0:
                print(self.l37[0],"Please go with the doctor!")
            elif len(self.l38)>0:
                print(self.l38[0],"Please go with the doctor!")
            elif len(self.l39)>0:
                print(self.l39[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==14:
            if len(self.l40)>0:
                print(self.l40[0],"Please go with the doctor!")
            elif len(self.l41)>0:
                print(self.l41[0],"Please go with the doctor!")
            elif len(self.l42)>0:
                print(self.l42[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==15:
            if len(self.l43)>0:
                print(self.l43[0],"Please go with the doctor!")
            elif len(self.l44)>0:
                print(self.l44[0],"Please go with the doctor!")
            elif len(self.l45)>0:
                print(self.l45[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==16:
            if len(self.l46)>0:
                print(self.l46[0],"Please go with the doctor!")
            elif len(self.l47)>0:
                print(self.l47[0],"Please go with the doctor!")
            elif len(self.l48)>0:
                print(self.l48[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==17:
            if len(self.l49)>0:
                print(self.l49[0],"Please go with the doctor!")
            elif len(self.l50)>0:
                print(self.l50[0],"Please go with the doctor!")
            elif len(self.l51)>0:
                print(self.l51[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==18:
            if len(self.l52)>0:
                print(self.l52[0],"Please go with the doctor!")
            elif len(self.l53)>0:
                print(self.l53[0],"Please go with the doctor!")
            elif len(self.l54)>0:
                print(self.l54[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==19:
            if len(self.l55)>0:
                print(self.l55[0],"Please go with the doctor!")
            elif len(self.l56)>0:
                print(self.l56[0],"Please go with the doctor!")
            elif len(self.l57)>0:
                print(self.l57[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        elif m==20:
            if len(self.l58)>0:
                print(self.l58[0],"Please go with the doctor!")
            elif len(self.l59)>0:
                print(self.l59[0],"Please go with the doctor!")
            elif len(self.l60)>0:
                print(self.l60[0],"Please go with the doctor!")
            else:
                print("No Patients at the moment. Have rest Doctor!")
        self.__init__() 
    def remove_patient(self):
        m=int(input('''Specializations : 
                1  for  Allergy and Immunology
                2  for  Anesthesiology 
                3  for  Dermatology
                4  for  Diagnostic radiology
                5  for  Emergency medicine
                6  for  Family medicine
                7  for  Internal medicine
                8  for  Medical genetics
                9  for  Neurology
                10 for  Nuclear medicine
                11 for  Obstetrics and gynecology
                12 for  Ophthalmology
                13 for  Pathology
                14 for  Pediatrics
                15 for  Physical medicine and rehabilitation
                16 for  Preventive medicine
                17 for  Psychiatry
                18 for  Radiation oncology
                19 for  Surgery
                20 for  Urology 
                Enter Specialization (1-20) from which you want to remove the patient :
                '''))
        if m==1:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l1:
                self.l1.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l2:
                self.l2.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            elif name in self.l3:
                self.l3.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 1 is",(self.l1+self.l2+self.l3))
            else:
                print("No such patient in Specialization 1")   
        if m==2:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l4:
                self.l4.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l5:
                self.l5.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            elif name in self.l6:
                self.l6.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 2 is",(self.l4+self.l5+self.l6))
            else:
                print("No such patient in Specialization 2")
        if m==3:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l7:
                self.l7.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l8:
                self.l8.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            elif name in self.l9:
                self.l9.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 3 is",(self.l7+self.l8+self.l9))
            else:
                print("No such patient in Specialization 3")   
        if m==4:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l10:
                self.l10.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l11:
                self.l11.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            elif name in self.l12:
                self.l12.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 4 is",(self.l10+self.l11+self.l12))
            else:
                print("No such patient in Specialization 4")
        if m==5:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l13:
                self.l13.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l14:
                self.l14.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            elif name in self.l15:
                self.l15.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 5 is",(self.l13+self.l14+self.l15))
            else:
                print("No such patient in Specialization 5")   
        if m==6:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l16:
                self.l16.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l17:
                self.l17.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            elif name in self.l18:
                self.l18.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 6 is",(self.l16+self.l17+self.l18))
            else:
                print("No such patient in Specialization 6")
        if m==7:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l19:
                self.l19.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l20:
                self.l20.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            elif name in self.l21:
                self.l21.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 7 is",(self.l19+self.l20+self.l21))
            else:
                print("No such patient in Specialization 7")   
        if m==8:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l22:
                self.l22.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l23:
                self.l23.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            elif name in self.l24:
                self.l24.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 8 is",(self.l22+self.l23+self.l24))
            else:
                print("No such patient in Specialization 8")
        if m==9:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l25:
                self.l25.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l26:
                self.l26.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            elif name in self.l27:
                self.l27.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 9 is",(self.l25+self.l26+self.l27))
            else:
                print("No such patient in Specialization 9")   
        if m==10:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l28:
                self.l28.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l29:
                self.l29.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            elif name in self.l30:
                self.l30.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 10 is",(self.l28+self.l29+self.l30))
            else:
                print("No such patient in Specialization 10")
        if m==11:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l31:
                self.l31.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l32:
                self.l32.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            elif name in self.l33:
                self.l33.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 11 is",(self.l31+self.l32+self.l33))
            else:
                print("No such patient in Specialization 11")   
        if m==12:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l34:
                self.l34.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l35:
                self.l35.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            elif name in self.l36:
                self.l36.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 12 is",(self.l34+self.l35+self.l36))
            else:
                print("No such patient in Specialization 12")
        if m==13:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l37:
                self.l37.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l38:
                self.l38.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            elif name in self.l39:
                self.l39.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 13 is",(self.l37+self.l38+self.l39))
            else:
                print("No such patient in Specialization 13")   
        if m==14:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l40:
                self.l40.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            elif name in self.l41:
                self.l41.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42)) 
            elif name in self.l42:
                self.l42.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 14 is",(self.l40+self.l41+self.l42))
            else:
                print("No such patient in Specialization 14")
        if m==15:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l43:
                self.l43.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l44:
                self.l44.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            elif name in self.l45:
                self.l45.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 15 is",(self.l43+self.l44+self.l45))
            else:
                print("No such patient in Specialization 15")   
        if m==16:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l46:
                self.l46.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l47:
                self.l47.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            elif name in self.l48:
                self.l48.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 16 is",(self.l46+self.l47+self.l48))
            else:
                print("No such patient in Specialization 16")
        if m==17:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l49:
                self.l49.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l50:
                self.l50.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            elif name in self.l51:
                self.l51.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 17 is",(self.l49+self.l50+self.l51))
            else:
                print("No such patient in Specialization 17")   
        if m==18:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l52:
                self.l52.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l53:
                self.l53.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            elif name in self.l54:
                self.l54.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 18 is",(self.l52+self.l53+self.l54))
            else:
                print("No such patient in Specialization 18")
        if m==19:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l55:
                self.l55.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l56:
                self.l56.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            elif name in self.l57:
                self.l57.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 19 is",(self.l55+self.l56+self.l57))
            else:
                print("No such patient in Specialization 19")   
        if m==20:
            name=input("Enter patient name you want to remove : ").upper()
            if name in self.l58:
                self.l58.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l59:
                self.l59.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            elif name in self.l60:
                self.l60.remove(name)
                print(name,"has been removed")
                print("Remaining patient in specialization 20 is",(self.l58+self.l59+self.l60))
            else:
                print("No such patient in Specialization 20")
        self.__init__()                
Hospital()
# Out:
# Program Options :
# Enter 1 to add a new patient
# Enter 2 to print all the patient
# Enter 3 to get next patient
# Enter 4 to remove a leaving patient
# Enter 5 to End the program
# Enter your choice :  1
# Specializations :
#                 1  for  Allergy and Immunology
#                 2  for  Anesthesiology
#                 3  for  Dermatology
#                 4  for  Diagnostic radiology
#                 5  for  Emergency medicine
#                 6  for  Family medicine
#                 7  for  Internal medicine
#                 8  for  Medical genetics
#                 9  for  Neurology
#                 10 for  Nuclear medicine
#                 11 for  Obstetrics and gynecology
#                 12 for  Ophthalmology
#                 13 for  Pathology
#                 14 for  Pediatrics
#                 15 for  Physical medicine and rehabilitation
#                 16 for  Preventive medicine
#                 17 for  Psychiatry
# ...
